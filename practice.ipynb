# %%
import pandas

# %%
pandas.__version__
# Out:
# '2.1.1'

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\haeun\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
import numpy as np

# %%
arr = np.arange(100, 105)
arr
# Out:
# array([100, 101, 102, 103, 104])

# %%
s = pd.Series(arr)
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int32

# %%
s = pd.Series(arr, dtype = 'int64')
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64

# %%
s = pd.Series(['부장', '차장', '대리', '사원', '인턴'])
s
# Out:
# 0    부장
# 1    차장
# 2    대리
# 3    사원
# 4    인턴
# dtype: object

# %%
s = pd.Series([91, 2.5, '스포츠', 4, 5.16])
s
# Out:
# 0      91
# 1     2.5
# 2     스포츠
# 3       4
# 4    5.16
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s[3]
# Out:
# 4

# %%
s[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 s[-1]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
# ...

# %%
s = pd.Series(['마케팅', '경영', '개발', '기획', '인사'], index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    마케팅
# b     경영
# c     개발
# d     기획
# e     인사
# dtype: object

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s['b']
# Out:
# '경영'

# %%
s[1]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12040\878419959.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[1]
# '경영'

# %%
s.iloc[1]
# Out:
# '경영'

# %%
s.iloc['b']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s.iloc['b']
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1711, in _iLocIndexer._getitem_axis(self, key, axis)
#    1709 key = item_from_zerodim(key)
#    1710 if not is_integer(key):
# -> 1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
#    1714 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
s[-1]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12040\2713154622.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[-1]
# '인사'

# %%
s = pd.Series(['마케팅', '경영', '개발'])
s
# Out:
# 0    마케팅
# 1     경영
# 2     개발
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.index = list('abc')
s
# Out:
# a    마케팅
# b     경영
# c     개발
# dtype: object

# %%
s.values
# Out:
# array(['마케팅', '경영', '개발'], dtype=object)

# %%
s.ndim
# Out:
# 1

# %%
s.shape
# Out:
# (5,)

# %%
s = pd.Series(['선화', '강호', np.nan, '소정', '우영'])
s
# Out:
# 0     선화
# 1     강호
# 2    NaN
# 3     소정
# 4     우영
# dtype: object

# %%
numbers = np.arange(50, 55)
s1 = pd.Series(numbers, dtype='float32')
s1
# Out:
# 0    50.0
# 1    51.0
# 2    52.0
# 3    53.0
# 4    54.0
# dtype: float32

# %%
s2 = pd.Series(['apple', np.nan, 'banana', 'kiwi', 'gubong'], index=['가', '나', '다', '라', '마'])
s2
# Out:
# 가     apple
# 나       NaN
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: object

# %%
f = ['apple', np.nan, 'banana', 'kiwi', 'gubong']
s3 = pd.Series(f, index=list('가나다라마'))
s3
# Out:
# 가     apple
# 나       NaN
# 다    banana
# 라      kiwi
# 마    gubong
# dtype: object

# %%
s = pd.Series(['김연아', '박세리', '김연경'], index=list('abc'))
s
# Out:
# a    김연아
# b    박세리
# c    김연경
# dtype: object

# %%
s[1]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_12040\878419959.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[1]
# '박세리'

# %%
s['a']
# Out:
# '김연아'

# %%
s[['a', 'b', 'c']]
# Out:
# a    김연아
# b    박세리
# c    김연경
# dtype: object

# %%
i = ['a', 'b']
s[i]
# Out:
# a    김연아
# b    박세리
# dtype: object

# %%
s[[True, False, True]]
# Out:
# a    김연아
# c    김연경
# dtype: object

# %%
i = [True, False, True]
s[i]
# Out:
# a    김연아
# c    김연경
# dtype: object

# %%
s = pd.Series([29, 99, np.nan, 11, 56], index=[list('abcde')])
s
# Out:
# a    29.0
# b    99.0
# c     NaN
# d    11.0
# e    56.0
# dtype: float64

# %%
s > 50
# Out:
# a    False
# b     True
# c    False
# d    False
# e     True
# dtype: bool

# %%
s[s>50]
# Out:
# b    99.0
# e    56.0
# dtype: float64

# %%
s[[False, True, False, False, True]]
# Out:
# b    99.0
# e    56.0
# dtype: float64

# %%
s.isnull()
# Out:
# a    False
# b    False
# c     True
# d    False
# e    False
# dtype: bool

# %%
s.isna()
# Out:
# a    False
# b    False
# c     True
# d    False
# e    False
# dtype: bool

# %%
s[s.isnull()]
# Out:
# c   NaN
# dtype: float64

# %%
s[s.isna()]
# Out:
# c   NaN
# dtype: float64

# %%
s.notnull()
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# dtype: bool

# %%
s.notna()
# Out:
# a     True
# b     True
# c    False
# d     True
# e     True
# dtype: bool

# %%
s[s.notnull()]
# Out:
# a    29.0
# b    99.0
# d    11.0
# e    56.0
# dtype: float64

# %%
s.[s.notna()]
# Out:
#   Cell In[81], line 1
#     s.[s.notna()]
#       ^
# SyntaxError: invalid syntax

# %%
s[1:3]
# Out:
# b    99.0
# c     NaN
# dtype: float64

# %%
s['b':'c']
# Out:
# b    99.0
# c     NaN
# dtype: float64

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
pd.DataFrame([[1, 2, 3],
             [4, 5, 6],
             [7, 8, 9]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
pd.DataFrame([[1, 2, 3],
             [4, 5, 6],
             [7, 8, 9]], columns = list('가나다'))
# Out:
#    가  나  다
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = {
    'name': ['kim', 'lee', 'park'],
    'age': [24, 27, 34],
    'children': [2, 1, 3]
}

pd.DataFrame(data)
# Out:
#    name  age  children
# 0   kim   24         2
# 1   lee   27         1
# 2  park   34         3

# %%
df = pd.DataFrame(data)
df
# Out:
#    name  age  children
# 0   kim   24         2
# 1   lee   27         1
# 2  park   34         3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'children'], dtype='object')

# %%
df.values
# Out:
# array([['kim', 24, 2],
#        ['lee', 27, 1],
#        ['park', 34, 3]], dtype=object)

# %%
df.dtypes
# Out:
# name        object
# age          int64
# children     int64
# dtype: object

# %%
df.T
# Out:
#             0    1     2
# name      kim  lee  park
# age        24   27    34
# children    2    1     3

# %%
df
# Out:
#    name  age  children
# 0   kim   24         2
# 1   lee   27         1
# 2  park   34         3

# %%
df.index = list('abc')
df
# Out:
#    name  age  children
# a   kim   24         2
# b   lee   27         1
# c  park   34         3

# %%
df
# Out:
#    name  age  children
# a   kim   24         2
# b   lee   27         1
# c  park   34         3

# %%
df['name']
# Out:
# a     kim
# b     lee
# c    park
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df[['name', 'children']]
# Out:
#    name  children
# a   kim         2
# b   lee         1
# c  park         3

# %%
df.rename(columns={'name': '이름'})
# Out:
#      이름  age  children
# a   kim   24         2
# b   lee   27         1
# c  park   34         3

# %%
df.rename({'name': '이름'}, axis=1)
df = df.rename({'a': 'z'}, axis=0)
df
# Out:
#    name  age  children
# z   kim   24         2
# b   lee   27         1
# c  park   34         3

# %%
df.rename({'name': '이름'}, axis=1)
# Out:
#      이름  age  children
# z   kim   24         2
# b   lee   27         1
# c  park   34         3

# %%
df.rename(columns={'name': '이름'}, inplace=True)
df
# Out:
#      이름  age  children
# z   kim   24         2
# b   lee   27         1
# c  park   34         3

# %%
data = {
    'food': ['KFC', 'MD', 'SF'],
    'price': [1000, 2000, 2500],
    'rating': [4.5, 3.9, 4.2]
}

df = pd.DataFrame(data)
df
# Out:
#   food  price  rating
# 0  KFC   1000     4.5
# 1   MD   2000     3.9
# 2   SF   2500     4.2

# %%
df[['food', 'rating']]
# Out:
#   food  rating
# 0  KFC     4.5
# 1   MD     3.9
# 2   SF     4.2

# %%
df.rename(columns={'food': 'place'})
# Out:
#   place  price  rating
# 0   KFC   1000     4.5
# 1    MD   2000     3.9
# 2    SF   2500     4.2

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
df['embark_town'].value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (891, 15)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.values
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
df.T
# Out:
#                      0          1            2            3            4    \
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df['pclass'].astype('int32').head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: int32

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['pclass'].astype('float32').head()
# Out:
# 0    3.0
# 1    1.0
# 2    3.0
# 3    1.0
# 4    3.0
# Name: pclass, dtype: float32

# %%
df['pclass'].astype('category').head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
df.sort_index().head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sort_index(ascending=False).head(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %%
df.sort_values(by='age').head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False

# %%
df.sort_values(by='age', ascending=False).head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.0000        S  First  man
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True
# 493        True  NaN    Cherbourg    no   True
# 96         True    A    Cherbourg    no   True
# 116        True  NaN   Queenstown    no   True

# %%
df.sort_values(by='class', ascending=False).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0           0       3    male  22.0      1      0  7.2500        S  Third
# 511         0       3    male   NaN      0      0  8.0500        S  Third
# 500         0       3    male  17.0      0      0  8.6625        S  Third
# 501         0       3  female  21.0      0      0  7.7500        Q  Third
# 502         0       3  female   NaN      0      0  7.6292        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 511    man        True  NaN  Southampton    no   True
# 500    man        True  NaN  Southampton    no   True
# 501  woman       False  NaN   Queenstown    no   True
# 502  woman       False  NaN   Queenstown    no   True

# %%
df.sort_values(by=['fare', 'age']).head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 179         0       3  male  36.0      0      0   0.0        S   Third  man
# 822         0       1  male  38.0      0      0   0.0        S   First  man
# 806         0       1  male  39.0      0      0   0.0        S   First  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 277         0       2  male   NaN      0      0   0.0        S  Second  man
# 413         0       2  male   NaN      0      0   0.0        S  Second  man
# 466         0       2  male   NaN      0      0   0.0        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 302        True  NaN  Southampton    no   True
# ...

# %%
df.sort_values(by=['fare', 'age'], ascending=[False, True]).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 27     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tips.sort_values(by=['total_bill', 'tip'], ascending=[False, False]).head(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4

# %%
tips.sort_values(by=['size', 'tip'], ascending=[False, True]).head(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 156       48.17  5.00    Male     No   Sun  Dinner     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 185       20.69  5.00    Male     No   Sun  Dinner     5
# 155       29.85  5.14  Female     No   Sun  Dinner     5
# 153       24.55  2.00    Male     No   Sun  Dinner     4

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.loc[5, 'class']
# Out:
# 'Third'

# %%
df.loc[2:5, ['age', 'fare', 'who']]
# Out:
#     age     fare    who
# 2  26.0   7.9250  woman
# 3  35.0  53.1000  woman
# 4  35.0   8.0500    man
# 5   NaN   8.4583    man

# %%
df.loc[2:5, 'class': 'deck'].head()
# Out:
#    class    who  adult_male deck
# 2  Third  woman       False  NaN
# 3  First  woman       False    C
# 4  Third    man        True  NaN
# 5  Third    man        True  NaN

# %%
df.loc[:6, 'class': 'deck']
# Out:
#    class    who  adult_male deck
# 0  Third    man        True  NaN
# 1  First  woman       False    C
# 2  Third  woman       False  NaN
# 3  First  woman       False    C
# 4  Third    man        True  NaN
# 5  Third    man        True  NaN
# 6  First    man        True    E

# %%
condition = df['who'] == 'man'

# %%
condition
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: who, Length: 891, dtype: bool

# %%
df[condition].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %%
df.loc[condition].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %%
df.loc[condition, 'age'] = 10
df[condition].head
# Out:
# <bound method NDFrame.head of      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  10.0      1      0   7.2500        S   Third
# 4           0       3  male  10.0      0      0   8.0500        S   Third
# 5           0       3  male  10.0      0      0   8.4583        Q   Third
# 6           0       1  male  10.0      0      0  51.8625        S   First
# 12          0       3  male  10.0      0      0   8.0500        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  10.0      0      0  10.5000        S  Second
# 884         0       3  male  10.0      0      0   7.0500        S   Third
# 886         0       2  male  10.0      0      0  13.0000        S  Second
# 889         1       1  male  10.0      0      0  30.0000        C   First
# 890         0       3  male  10.0      0      0   7.7500        Q   Third
#
# ...

# %%
df = sns.load_dataset('titanic')

# %%
con = df['age'] > 30

# %%
df.loc[con].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 3   woman       False    C  Southampton   yes  False
# 4     man        True  NaN  Southampton    no   True
# 6     man        True    E  Southampton    no   True
# 11  woman       False    C  Southampton   yes   True

# %%
con1 = df['fare'] > 30
con2 = df['who'] == 'woman'
df.loc[con1 & con2]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 25          1       3  female  38.0      1      5   31.3875        S  Third
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 853         1       1  female  16.0      0      1   39.4000        S  First
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[con1 | con2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
con1 = df['age'] > 30
con2 = df['sex'] == 'male'
df.loc[con1 & con2].sort_values(by='fare', ascending=False).head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked  class  \
# 679         1       1  male  36.0      0      1  512.3292        C  First
# 737         1       1  male  35.0      0      0  512.3292        C  First
# 438         0       1  male  64.0      1      4  263.0000        S  First
# 332         0       1  male  38.0      0      1  153.4625        S  First
# 660         1       1  male  50.0      2      0  133.6500        S  First
# 390         1       1  male  36.0      1      2  120.0000        S  First
# 659         0       1  male  58.0      0      2  113.2750        C  First
# 698         0       1  male  49.0      1      1  110.8833        C  First
# 544         0       1  male  50.0      1      0  106.4250        C  First
# 245         0       1  male  44.0      2      0   90.0000        Q  First
#
#      who  adult_male deck  embark_town alive  alone
# 679  man        True    B    Cherbourg   yes  False
# ...
